# %%
# import library
import pymoo
from pymoo.model.problem import Problem
import pandas
import pycaret
import numpy as np
import math
import matplotlib.pyplot as plt

from pycaret.regression import load_model

# %%
# load ML data

ML_data = pandas.read_csv("./NSGA2_data_2021_08_11_v1_N1000.csv")

# %%
# load simulation data

sim_data = pandas.read_csv("./simulation_data_2021_08_11_v1_N1000.csv")

# %%
Lmt_ML = ML_data["Lmt"]
Lmt_sim = sim_data["Lmt"]


plt.scatter(Lmt_ML, Lmt_sim)

plt.xlabel("ML model Lmt value [mH]")
plt.ylabel("sim model Lmt value [mH]")
plt.grid(True)

ML_data["Lmt"][0]
sim_data["Lmt"][0]

#plt.plot([5,25], [5,25], 'k-')

plt.rcParams["figure.figsize"] = (7,6)

# %%
Lmr_ML = ML_data["Lmr"]
Lmr_sim = sim_data["Lmr"]


plt.scatter(Lmr_ML, Lmr_sim)

plt.xlabel("ML model Lmr value [mH]")
plt.ylabel("sim model Lmr value [mH]")
plt.grid(True)

#plt.plot([5,25], [5,25], 'k-')

plt.rcParams["figure.figsize"] = (7,6)

# %%
Llt_ML = ML_data["Llt"]
Llt_sim = sim_data["Lmlt"]


plt.scatter(Llt_ML, Llt_sim)

plt.xlabel("ML model Llt value [mH]")
plt.ylabel("sim model Llt value [mH]")
plt.grid(True)

#plt.plot([5,25], [5,25], 'k-')

plt.rcParams["figure.figsize"] = (7,6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\NEC_stable\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Llt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21700/2434683070.py in <module>
# ----> 1 Llt_ML = ML_data["Llt"]
#       2 Llt_sim = sim_data["Lmlt"]
#       3
#       4
#       5 plt.scatter(Llt_ML, Llt_sim)
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Llt'

# %%
copperloss_tx_ML = ML_data["copperloss_tx"]
copperloss_tx_sim = sim_data["copperloss_tx"]


plt.scatter(copperloss_tx_ML, copperloss_tx_sim)

plt.xlabel("ML model copperloss_tx value [W]")
plt.ylabel("sim model copperloss_tx value [W]")
plt.grid(True)

#plt.plot([1,2], [1,2], 'k-')

plt.rcParams["figure.figsize"] = (7,6)

# %%
copperloss_rx_ML = ML_data["copperloss_rx"]
copperloss_rx_sim = sim_data["copperloss_rx"]


plt.scatter(copperloss_rx_ML, copperloss_rx_sim)

plt.xlabel("ML model copperloss_rx value [W]")
plt.ylabel("sim model copperloss_rx value [W]")
plt.grid(True)

#plt.plot([0.7,1.4], [0.7,1.4], 'k-')

plt.rcParams["figure.figsize"] = (7,6)
