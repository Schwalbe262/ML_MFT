# %%
# 1. import module

import pandas as pd
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from pycaret.regression import *

from sklearn.model_selection import train_test_split 
from sklearn import metrics
from lightgbm import LGBMRegressor
import lightgbm as lgb
from sklearn.model_selection import KFold

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error 


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.max_seq_items = None



from py_module.load_data import load_data
from py_module.plot_data import plot_histogram
from py_module.regression import *
from py_module.pre_processing import *
from py_module.verify import *
from py_module.etc import *
from py_module.compare import *

# %%
# 2. data import

#raw_data = np.loadtxt("../data/loss_20220608_105250_N14183.csv",delimiter=",")
#raw_data = np.loadtxt("../data/loss_20220609_130342_N39022.csv",delimiter=",")
raw_data = np.loadtxt("../data/loss_20220610_132219_N61966.csv",delimiter=",")
#raw_data = np.loadtxt("../data/coupling.csv",delimiter=",")
#raw_data = np.loadtxt("../data/loss.csv",delimiter=",")

column_names = ["N1","w1","l1","l2","h1","space1","space2","space3","space4","coil_width1","coil_width2","move_z1","move_z2","offset_z1","offset_z2","null","freq","Rt","Rr"]
#column_names = ["width0","width1","height0","height1","move","coil0_width","coil1_width","gap0","gap1","freq","k12","k13","k23"]
#column_names = ["width0","width1","height0","height1","move","coil0_width","coil1_width","gap0","gap1","0","freq","loss1","loss2","loss3"]

pd_data = pd.DataFrame(raw_data, columns=column_names)

pd_data.head()
# Out:
#      N1     w1    l1    l2     h1  space1  space2  space3  space4  \
# 0   5.0   80.0  25.0  90.0  131.0    18.0    28.0    12.0    40.0
# 1  13.0   25.0  15.0  98.0  128.0    48.0    46.0    16.0    40.0
# 2  15.0  175.0  20.0  82.0  216.0    32.0    42.0    12.0     6.0
# 3   9.0  115.0  25.0  98.0  151.0    42.0    34.0    32.0    44.0
# 4   9.0  160.0  50.0  70.0  114.0    36.0     6.0    50.0    40.0
#
#    coil_width1  coil_width2  move_z1  move_z2  offset_z1  offset_z2  null  \
# 0          8.0          4.0      3.0      3.0       -9.5      -13.0   0.0
# 1          3.0          4.0      1.0      3.0       -5.0       -2.5   0.0
# 2          7.5          6.5      3.0      5.0        1.5        4.5   0.0
# 3          5.5          9.0      3.0      2.0        7.0      -19.5   0.0
# 4          7.0          2.5      2.5      5.0       -2.5      -18.0   0.0
#
#    freq          Rt          Rr
# 0  30.0   31.247300   49.470518
# 1  30.0  250.872445  128.341621
# 2  30.0  254.471631  198.577852
# 3  30.0  108.095221  106.964241
# 4  30.0  183.753678  261.179291

# %%
# 4. check outlier

plt.figure(figsize=(16, 12))
for i, colName in enumerate(list(pd_data.columns)) :
    plt.subplot(4, 5, i+1)
    sns.boxplot(x=pd_data.loc[:, colName])
plt.tight_layout()
plt.show()

# %%
# 5. check data distribution

plt.figure(figsize=(16, 12))
for i, colName in enumerate(list(pd_data.columns)) :
    plt.subplot(4, 5, i+1)
    sns.histplot(pd_data.loc[:, colName])
plt.tight_layout()
plt.show()

# %%
# 7. define outlier search function
def get_outlier(df=None, column=None, weight=1.5):
    
    # column 데이터만 추출, 1/4 분위와 3/4 분위 지점을 np.percentile로 구함. 
    data = df[column]
    quantile_25 = np.percentile(data.values, 25)  # 1/4 분위
    quantile_75 = np.percentile(data.values, 75)  # 3/4 분위
    
    # IQR을 구하고, IQR에 1.5를 곱하여 최대값과 최소값 지점 구함. 
    iqr = quantile_75 - quantile_25
    iqr_weight = iqr * weight
    lowest_val = quantile_25 - iqr_weight  # 이상치 최소 기준
    highest_val = quantile_75 + iqr_weight # 이상치 최대 기준
    
    # 최대값 보다 크거나, 최소값 보다 작은 값을 아웃라이어로 설정하고 DataFrame index 반환. 
    outlier_index = data[(data < lowest_val) | (data > highest_val)].index
    
    return outlier_index

col_input = list(pd_data.columns)[:-3]
#col_input = list(pd_data.columns)

# outlier 탐색 및 제거
outlier_index = {}
for i, colName in enumerate(col_input):
     outlier_index[i] = get_outlier(df=pd_data, column=f'{colName}', weight=1.5)
outlier_index

# 각각의 숫자들 리스트 안에 넣기
outlier_list = []
for i in range(len(outlier_index)):
    if list(outlier_index[i].values) == []:
        continue
    outlier_list.append(list(outlier_index[i].values))


# 리스트 안의 리스트들을 하나로 합치기
outlier_list = sum(outlier_list , [])
print('개수:', len(outlier_list))

# 중복 숫자 제거
outlier_list = set(outlier_list)
print('개수:', len(outlier_list))

# 다시 리스트 타입으로 변환
outlier_list = list(outlier_list)
print(type(outlier_list))

# 리스트 숫자 정렬
outlier_list.sort()

# outlier를 갖는 index에 해당하는 data drop
for i in outlier_list:
    pd_data.drop(i, axis=0, inplace=True)
pd_data.shape
# Out:
# 개수: 2668
# 개수: 2644
# <class 'list'>
# (59322, 19)

# %%
col_input
# Out:
# ['N1',
#  'w1',
#  'l1',
#  'l2',
#  'h1',
#  'space1',
#  'space2',
#  'space3',
#  'space4',
#  'coil_width1',
#  'coil_width2',
#  'move_z1',
#  'move_z2',
#  'offset_z1',
#  'offset_z2',
#  'null',
#  'freq',
#  'Rt',
#  'Rr']

# %%
# split input/output

X = pd_data.drop(columns="freq").drop(columns="null").drop(columns="Rt").drop(columns="Rr")
Y = pd_data["Rr"]/100**2

#X = pd_data.drop(columns="k12").drop(columns="k13").drop(columns="k23")
#Y = pd_data["k12"]

#X = pd_data.drop(columns="loss1").drop(columns="loss2").drop(columns="loss3")
#Y = pd_data["loss1"]

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state = 765)

# %%
#model = LGBMRegressor(random_state=765, n_estimators=2000, learning_rate=0.05, num_leaves=31)
model = LGBMRegressor(random_state=765, n_estimators=10000, learning_rate=0.05, num_leaves=31)
model.fit(X_train,Y_train)

print(model)
# Out:
# LGBMRegressor(learning_rate=0.05, n_estimators=2000, random_state=765)

# %%
col_input = list(X.columns)

# 교차 검증용 데이터셋 구성
df_trains = []
df_valids = []

# MAPE 정의
def def_MAPE(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 

# MPE 정의
def def_MPE(y_test, y_pred): 
	return np.mean((y_test - y_pred) / y_test) * 100

# KFold 검증
i = 0
plt.figure(figsize=(25, 5))
kfold = KFold(n_splits=5, random_state=765, shuffle=True)
for train_idx, test_idx in kfold.split(X[col_input]):

    # fold 후 train, test set 분할
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    Y_train, Y_test = Y.iloc[train_idx], Y.iloc[test_idx]

    # regression model 생성
    model.fit(X_train, Y_train)

    # 예측
    fold_pred = model.predict(X_test)

    # 성능계산
    R2 = r2_score(Y_test, fold_pred)
    MAE = mean_absolute_error(Y_test, fold_pred)
    MSE = mean_squared_error(Y_test, fold_pred)
    RMSE = np.sqrt(MSE)
    MAPE = def_MAPE(Y_test, fold_pred)
    MPE = def_MPE(Y_test, fold_pred)

    print([R2, MAE,MSE,RMSE,MAPE,MPE])

    plt.subplot(1, 5, i+1)
    plt.scatter(Y_test, fold_pred)
    plt.xlabel("real value", fontsize=15)
    plt.ylabel("expected value", fontsize=15)
    plt.grid(True)
    plt.xlim(0, 0.04)
    plt.ylim(0, 0.04)
    plt.plot([0, 0.04], [0, 0.04], ls="--", c=".2", linewidth=3.0)
    i = i+1

plt.tight_layout()
plt.show()
# Out:
# [0.9835095628771242, 0.0006197361893878094, 1.0310594169226954e-06, 0.0010154109596230954, 5.914521780915411, -1.0218433213156237]
# [0.9858230889699623, 0.0006039767839156086, 9.127109093853735e-07, 0.0009553590473666817, 5.929675874957326, -0.7075233796605966]
# [0.9846952770239967, 0.000640096956618053, 9.99558043607864e-07, 0.0009997789973828536, 6.3150853621528755, -0.6696214679804396]
# [0.9862131247918617, 0.0006074677489112222, 8.613059456550954e-07, 0.0009280657011521842, 5.824517583694086, -0.4191820478493876]
# [0.9860474727854429, 0.0005880262399745124, 8.575093129834615e-07, 0.0009260179873973623, 6.08260761641221, -0.7791489629688283]

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    "n_estimators" : [1000,3000,10000],
    'n_jobs' : [-1],
    'learning_rate': [0.05],
    'max_depth' : [-1,2,3,4,5,10,20,30,50],
    'num_leaves' : [31,60,80,100,127],
    }

#cv=5 5번의 교차검증.
grid = GridSearchCV(LGBMRegressor(random_state=0), verbose=2, param_grid = parameters, cv=kfold)
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   9.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.3s remaining:    0.0s
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31, total=  11.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   3.6s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   3.7s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   2.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.2s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   2.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.7s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.8s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.6s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   2.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.8s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.3s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.2s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.2s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.2s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   3.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   4.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   4.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   3.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   4.2s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   5.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   5.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   4.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   5.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   4.7s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   6.3s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.3s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.3s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.6s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.6s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.7s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.5s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  17.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.4s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.6s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.1s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.0s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  19.8s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.3s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.3s
# [CV] learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=-1, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  21.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.3s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.2s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   0.9s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   0.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   0.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   0.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   0.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   0.8s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   1.0s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   0.7s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   2.6s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   2.6s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   2.3s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   2.5s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   2.4s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   2.6s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   2.6s
# [CV] learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=2, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   2.5s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.4s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   0.9s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   0.9s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.1s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   1.1s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   1.1s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   0.9s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   3.4s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   3.4s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=80, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   3.4s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=100, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   3.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   3.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=10000, n_jobs=-1, num_leaves=127, total=   3.1s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.6s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   0.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   1.5s
# ...
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.4s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.6s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.4s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.3s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.0s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.3s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.2s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  19.9s
# [CV] learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=30, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  19.8s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=31, total=   0.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=60, total=   1.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=80, total=   1.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=100, total=   1.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   1.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   2.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=1000, n_jobs=-1, num_leaves=127, total=   1.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=31, total=   1.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.1s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=60, total=   3.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   3.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   4.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   4.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   3.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=80, total=   3.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   4.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   4.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   4.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   4.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=100, total=   4.7s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=3000, n_jobs=-1, num_leaves=127, total=   5.8s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=31, total=   6.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.5s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.5s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=60, total=  10.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.5s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.4s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=80, total=  13.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.9s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.3s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.2s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=100, total=  16.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.0s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.2s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  20.6s
# [CV] learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127
# [CV]  learning_rate=0.05, max_depth=50, n_estimators=10000, n_jobs=-1, num_leaves=127, total=  19.7s
# [Parallel(n_jobs=1)]: Done 675 out of 675 | elapsed: 48.0min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=765, shuffle=True),
#              estimator=LGBMRegressor(random_state=0),
#              param_grid={'learning_rate': [0.05],
#                          'max_depth': [-1, 2, 3, 4, 5, 10, 20, 30, 50],
#                          'n_estimators': [1000, 3000, 10000], 'n_jobs': [-1],
#                          'num_leaves': [31, 60, 80, 100, 127]},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 4,
#  'n_estimators': 10000,
#  'n_jobs': -1,
#  'num_leaves': 31}

# %%
#model = LGBMRegressor(random_state=765, learning_rate=0.05, max_depth=10, n_estimators=5000)
tuned_model = LGBMRegressor(random_state=765, **grid.best_params_)
tuned_model.fit(X_train,Y_train)

print(tuned_model)
# Out:
# LGBMRegressor(learning_rate=0.05, max_depth=4, n_estimators=10000,
#               random_state=765)

# %%
# 교차 검증용 데이터셋 구성
df_trains = []
df_valids = []

# MAPE 정의
def def_MAPE(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 

# MPE 정의
def def_MPE(y_test, y_pred): 
	return np.mean((y_test - y_pred) / y_test) * 100

# KFold 검증
i = 0
plt.figure(figsize=(25, 5))
kfold = KFold(n_splits=5, random_state=765, shuffle=True)
for train_idx, test_idx in kfold.split(X[col_input]):

    # fold 후 train, test set 분할
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    Y_train, Y_test = Y.iloc[train_idx], Y.iloc[test_idx]

    # regression model 생성
    tuned_model.fit(X_train, Y_train)

    # 예측
    fold_pred = tuned_model.predict(X_test)

    # 성능계산
    R2 = r2_score(Y_test, fold_pred)
    MAE = mean_absolute_error(Y_test, fold_pred)
    MSE = mean_squared_error(Y_test, fold_pred)
    RMSE = np.sqrt(MSE)
    MAPE = def_MAPE(Y_test, fold_pred)
    MPE = def_MPE(Y_test, fold_pred)

    print([R2, MAE,MSE,RMSE,MAPE,MPE])

    plt.subplot(1, 5, i+1)
    plt.scatter(Y_test, fold_pred)
    plt.xlabel("real value", fontsize=15)
    plt.ylabel("expected value", fontsize=15)
    plt.grid(True)
    plt.xlim(0, 100)
    plt.ylim(0, 100)
    plt.plot([0, 100], [0, 100], ls="--", c=".2", linewidth=3.0)
    i = i+1

plt.tight_layout()
plt.show()
# Out:
# [0.9958255566144492, 0.9140250937075481, 1.9941484544223416, 1.4121432131417626, 4.949711517847335, 0.002318099733269799]
# [0.9954067757918389, 0.9500328800056479, 2.252135805418638, 1.5007117662691387, 4.881763796540582, -0.028577398065501528]
# [0.995688961094157, 0.9443259502352217, 2.068698070153125, 1.4382969339302385, 4.961097882169882, -0.3890619051306933]
# [0.9963029117734534, 0.889377177241239, 1.8267548140643102, 1.3515749383827411, 5.032781846390559, -0.016524105625636925]
# [0.9957007888645959, 0.9235714194097383, 2.0459684638366453, 1.430373539966622, 5.003386000144607, -0.17458481899094844]

# %%
train_data = pd.concat([X_train,pd.DataFrame(Y_train)], axis=1)

test_data = pd.concat([X_test,pd.DataFrame(Y_test)], axis=1)


train_data.head()
# Out:
#          N1     w1    l1     l2     h1  space1  space2  space3  space4  \
# 45227   5.0  100.0  30.0   95.0  117.0    50.0    44.0     8.0    36.0
# 46409   9.0   40.0  40.0   97.0  168.0    26.0    50.0    46.0    16.0
# 50791   8.0  165.0  25.0   84.0  120.0    30.0    28.0    50.0    42.0
# 51979  10.0  120.0  30.0  100.0  150.0    42.0    10.0    38.0    18.0
# 45584   7.0   95.0  10.0   86.0  104.0     4.0    24.0    36.0     8.0
#
#        coil_width1  coil_width2  move_z1  move_z2  offset_z1  offset_z2  \
# 45227          4.0          6.0      2.5      2.0       14.5      -14.5
# 46409          9.5          6.5      4.5      2.5      -15.5      -11.0
# 50791          5.0          4.0      1.5      2.5      -12.5        1.0
# 51979         10.0          7.5      1.5      5.0        9.0      -10.0
# 45584          7.5          6.5      5.0      2.0        3.0       12.0
#
#              Rr
# 45227  0.004842
# 46409  0.007815
# 50791  0.017926
# 51979  0.008751
# 45584  0.006371

# %%
parameter = "Rr"

verify_plot(model, train_data, test_data, parameter, xlim=[0,0.04], ylim=[0,0.04], legend=True)
# Out:
# array([9.91547342e-01, 5.06385011e-04, 7.34436556e-07, 8.56992740e-04,
#        5.02012192e+00])

# %%
verify_plot(model, train_data, test_data, parameter, xlim=[0,100], ylim=[0,100], legend=True)
# Out:
# array([0.99328528, 1.06612185, 3.19549591, 1.78759501, 4.34227695])

# %%
from lightgbm import plot_importance

fig, ax = plt.subplots(figsize=(11,8))
plot_importance(model, ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
import joblib

joblib.dump(model, 'Rr_0610.pkl')
# Out:
# ['Rr_0610.pkl']

# %%
load_model = joblib.load('leakage_inductance.pkl')

# %%
verify_plot(load_model, train_data, test_data, parameter, xlim=[0,100], ylim=[0,100], legend=True)
# Out:
# array([0.99570079, 0.92357142, 2.04596846, 1.43037354, 5.003386  ])
