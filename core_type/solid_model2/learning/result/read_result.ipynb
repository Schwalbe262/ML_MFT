# %%
# import library
import pandas
import numpy as np
import math
import matplotlib.pyplot as plt

import pymoo
from pymoo.model.problem import Problem

import pandas as pd


import joblib

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)


read_data = pd.read_csv("../result/result_0620_F111_N3000_amorphous.csv")


read_data = read_data[read_data["copperloss_tx"]<70]
read_data = read_data[read_data["N1"]<9]


read_data
# Out:
#     Unnamed: 0   N1    w1    l1     l2     h1     per  space1  space2  space3  \
# 73           8  8.0  46.0  28.0  104.0   84.0  3500.0    25.0    25.0    14.0
# 74          64  8.0  46.0  28.0  100.0   84.0  3500.0    25.0    25.0    11.0
# 75          57  8.0  46.0  29.0   98.0   84.0  3500.0    25.0    25.0    14.0
# 76          50  8.0  46.0  28.0  100.0   84.0  3500.0    25.0    25.0    11.0
# 78          97  8.0  46.0  29.0  108.0   99.0  3500.0    26.0    26.0    15.0
# 79          52  8.0  46.0  29.0  104.0   99.0  3500.0    26.0    26.0    15.0
# 80          36  8.0  46.0  29.0  100.0   85.0  3500.0    26.0    26.0    14.0
# 81          16  8.0  46.0  29.0  104.0   85.0  3500.0    26.0    26.0    14.0
# 82          81  8.0  46.0  29.0  100.0   91.0  3500.0    26.0    26.0    14.0
# 83           9  8.0  46.0  29.0   99.0   85.0  3500.0    26.0    26.0    12.0
# 84          19  8.0  46.0  29.0  100.0   99.0  3500.0    26.0    26.0    12.0
# ...
