# %%
#import module (library)

import pandas as pd
import pycaret
import numpy as np
import math
import matplotlib.pyplot as plt
from pycaret.regression import *

from pycaret.regression import load_model

import plotly.io as pio
pio.renderers.default = 'iframe_connected'

import time

from datetime import datetime

# %%
# import module (user defined function)

from py_module.load_data import load_data
from py_module.plot_data import plot_histogram
from py_module.regression import *
from py_module.pre_processing import *
from py_module.verify import *

# %%
# import raw_data (from csv file)

filename = "./Data_2021_10_14_v1 (N98923)/Data.csv" # csv file directory and name

raw_data = load_data(fn=filename, pp=1)

# %%
# plot raw_data histogram (for data pre-process / option-task)

## - parameter
# input : N1, N2, d1, d2, freq, move_tx, move_rx, offset_tx, offset_rx, per, space1, space2, space3, space4, l1, l2, h1, w1
# output : Lmt, Lmr, Llt, Llr, k, R1, R2

## - opt
# bins : (default : 100)
# plt_size : (default : [6,5])
# grid_en : (default : False)
# title_en : (default : False)
# title : (default : "")
# fontsize : (default : {}) (see : https://www.delftstack.com/ko/howto/matplotlib/how-to-set-the-figure-title-and-axes-labels-font-size-in-matplotlib/)

parameter = "Llt" # desired parameter as a histogram
title = parameter # plot title name
fontsize = {'axes.titlesize' : 20, 'xtick.labelsize' : 10, 'ytick.labelsize' : 10}


plot_histogram(raw_data, parameter, plt_size=[4,3], grid_en=True, title_en=True, title=title, fontsize=fontsize)

# %%
## === dataset pre-processing ===

# drop output data except for target output

parameter = "Llt" # target output pamareter
processed_data = drop_output(raw_data, parameter)



# cut data
## - opt
# lo : lower bound value (default : -inf)
# hi : upper bound value (default : inf)

processed_data = cut_data(processed_data, parameter="Llt", lo=0.1, hi=40)



# add feature
# 기존에 존재하는 input parameter들을 이용해서 물리적인 의미를 갖는 새로운 파라미터를 만들어 낼 시 모델의 성능을 증가시킬 수 있음
# ex> 변압기 자화 인덕턴스는 턴수의 제곱에 비례하므로 턴수의 제곱에 해당하는 파라미터를 새로 만들어 자화인덕터 regression 모델을 만들 경우 모델 성능 증가

new_feature_names = []

processed_data = add_feature(processed_data, parameter, new_feature_names = new_feature_names)



processed_data
# Out:
#        N1  N2    d1    d2     freq  move_tx  move_rx  offset_tx  offset_rx  \
# 0       8   8   6.0   9.7  49000.0        2        5          7         -9
# 1       8   8  11.7  10.7  49000.0        6        4         18         -5
# 2       8   8   9.0   5.4  49000.0        4        1          9        -18
# 3       8   8   9.5   4.2  49000.0        6        3         14         -7
# 4      11  11   7.5  10.3  58000.0        1        2         13        -17
# ...    ..  ..   ...   ...      ...      ...      ...        ...        ...
# 97610   9   9   8.4   9.2  42000.0        7        2          8        -14
# 97611   5   5  11.4   8.9  25000.0        3        4         12         -6
# 97612   5   5   8.6   9.6  25000.0        2        2         17         -2
# 97613   5   5  11.0   3.6  25000.0        1        7         18        -12
# 97614   5   5   9.8   6.3  25000.0        5        3         16        -20
#
#         per  space1  space2  space3  space4  l1  l2   h1   w1        Llt
# 0      1480       1      23       3      55  19  41  166   24   6.704324
# 1      1160       5      47       3      31  31  72  251  248  13.703235
# 2      4192       5      31       7      28  33  40  191  212  19.559244
# 3      3419       1      21       6      38  15  30  185  221  16.173505
# 4      4445       7      50       6      46  16  69  207  241  35.181363
# ...     ...     ...     ...     ...     ...  ..  ..  ...  ...        ...
# 97610  2483       9      59       9      35  30  71  235  105  14.449801
# 97611  1838       2      50       3      47  23  62  161  118   7.164551
# 97612  4913       1      21       3      35  29  51  110   80   3.697227
# 97613  4437       1      33       4      31  26  59  131  170   8.532143
# 97614  2309       9      37       4      26  17  71  145   98   5.654719
#
# [97615 rows x 19 columns]

# %%
# compare algorithm
# 여러 regression 알고리즘 중 가장 높은 성능을 내는 알고리즘 탐색

# activate logger
[model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm="lightgbm", frac_ratio=0.9, save_en=False, save_model_name="model", new_feature_names=new_feature_names)


# variable
algorithm_list = models().index
except_list = ["kr","svm"] # algorithm list to exclude from train
result = []


# eleminate algorithm in exception list
for al_name in except_list :

    algorithm_list = algorithm_list[algorithm_list!=al_name]

    
# train each algorithm
for al_name in algorithm_list :

    [model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm=al_name, new_feature_names=new_feature_names)
    [R2, MAE, MSE, RMSE, MPE] = verify_model(model, data_seen, data_unseen, parameter)
    result.append([al_name, R2, MAE, MSE, RMSE, MPE])


# compare model result
pd.DataFrame(result,columns = ["algorithm","R2","MAE","MSE","RMSE","MPE(%)"]).sort_values(by='R2' ,ascending=False).reset_index(drop=True)
# Out:
# <style type="text/css">
# #T_c6206_row10_col0, #T_c6206_row10_col1, #T_c6206_row10_col2, #T_c6206_row10_col3, #T_c6206_row10_col4, #T_c6206_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c6206_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6206_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6206_row0_col0" class="data row0 col0" >0.1339</td>
#       <td id="T_c6206_row0_col1" class="data row0 col1" >0.0488</td>
#       <td id="T_c6206_row0_col2" class="data row0 col2" >0.2210</td>
#       <td id="T_c6206_row0_col3" class="data row0 col3" >0.9890</td>
#       <td id="T_c6206_row0_col4" class="data row0 col4" >0.0547</td>
#       <td id="T_c6206_row0_col5" class="data row0 col5" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6206_row1_col0" class="data row1 col0" >0.1360</td>
#       <td id="T_c6206_row1_col1" class="data row1 col1" >0.0483</td>
#       <td id="T_c6206_row1_col2" class="data row1 col2" >0.2198</td>
#       <td id="T_c6206_row1_col3" class="data row1 col3" >0.9894</td>
#       <td id="T_c6206_row1_col4" class="data row1 col4" >0.0562</td>
#       <td id="T_c6206_row1_col5" class="data row1 col5" >0.0896</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6206_row2_col0" class="data row2 col0" >0.1346</td>
#       <td id="T_c6206_row2_col1" class="data row2 col1" >0.0433</td>
#       <td id="T_c6206_row2_col2" class="data row2 col2" >0.2080</td>
#       <td id="T_c6206_row2_col3" class="data row2 col3" >0.9902</td>
#       <td id="T_c6206_row2_col4" class="data row2 col4" >0.0541</td>
#       <td id="T_c6206_row2_col5" class="data row2 col5" >0.0867</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6206_row3_col0" class="data row3 col0" >0.1371</td>
#       <td id="T_c6206_row3_col1" class="data row3 col1" >0.0488</td>
#       <td id="T_c6206_row3_col2" class="data row3 col2" >0.2209</td>
#       <td id="T_c6206_row3_col3" class="data row3 col3" >0.9893</td>
#       <td id="T_c6206_row3_col4" class="data row3 col4" >0.0567</td>
#       <td id="T_c6206_row3_col5" class="data row3 col5" >0.0855</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c6206_row4_col0" class="data row4 col0" >0.1357</td>
#       <td id="T_c6206_row4_col1" class="data row4 col1" >0.0393</td>
#       <td id="T_c6206_row4_col2" class="data row4 col2" >0.1982</td>
#       <td id="T_c6206_row4_col3" class="data row4 col3" >0.9912</td>
#       <td id="T_c6206_row4_col4" class="data row4 col4" >0.0516</td>
#       <td id="T_c6206_row4_col5" class="data row4 col5" >0.0859</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c6206_row5_col0" class="data row5 col0" >0.1361</td>
#       <td id="T_c6206_row5_col1" class="data row5 col1" >0.0416</td>
#       <td id="T_c6206_row5_col2" class="data row5 col2" >0.2038</td>
#       <td id="T_c6206_row5_col3" class="data row5 col3" >0.9907</td>
#       <td id="T_c6206_row5_col4" class="data row5 col4" >0.0563</td>
#       <td id="T_c6206_row5_col5" class="data row5 col5" >0.0895</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c6206_row6_col0" class="data row6 col0" >0.1387</td>
#       <td id="T_c6206_row6_col1" class="data row6 col1" >0.0455</td>
#       <td id="T_c6206_row6_col2" class="data row6 col2" >0.2133</td>
#       <td id="T_c6206_row6_col3" class="data row6 col3" >0.9899</td>
#       <td id="T_c6206_row6_col4" class="data row6 col4" >0.0534</td>
#       <td id="T_c6206_row6_col5" class="data row6 col5" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c6206_row7_col0" class="data row7 col0" >0.1414</td>
#       <td id="T_c6206_row7_col1" class="data row7 col1" >0.0504</td>
#       <td id="T_c6206_row7_col2" class="data row7 col2" >0.2246</td>
#       <td id="T_c6206_row7_col3" class="data row7 col3" >0.9891</td>
#       <td id="T_c6206_row7_col4" class="data row7 col4" >0.0562</td>
#       <td id="T_c6206_row7_col5" class="data row7 col5" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c6206_row8_col0" class="data row8 col0" >0.1381</td>
#       <td id="T_c6206_row8_col1" class="data row8 col1" >0.0497</td>
#       <td id="T_c6206_row8_col2" class="data row8 col2" >0.2229</td>
#       <td id="T_c6206_row8_col3" class="data row8 col3" >0.9890</td>
#       <td id="T_c6206_row8_col4" class="data row8 col4" >0.0555</td>
#       <td id="T_c6206_row8_col5" class="data row8 col5" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c6206_row9_col0" class="data row9 col0" >0.1390</td>
#       <td id="T_c6206_row9_col1" class="data row9 col1" >0.0442</td>
#       <td id="T_c6206_row9_col2" class="data row9 col2" >0.2102</td>
#       <td id="T_c6206_row9_col3" class="data row9 col3" >0.9904</td>
#       <td id="T_c6206_row9_col4" class="data row9 col4" >0.0520</td>
#       <td id="T_c6206_row9_col5" class="data row9 col5" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c6206_row10_col0" class="data row10 col0" >0.1371</td>
#       <td id="T_c6206_row10_col1" class="data row10 col1" >0.0460</td>
#       <td id="T_c6206_row10_col2" class="data row10 col2" >0.2143</td>
#       <td id="T_c6206_row10_col3" class="data row10 col3" >0.9898</td>
#       <td id="T_c6206_row10_col4" class="data row10 col4" >0.0547</td>
#       <td id="T_c6206_row10_col5" class="data row10 col5" >0.0869</td>
#     </tr>
#     <tr>
#       <th id="T_c6206_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_c6206_row11_col0" class="data row11 col0" >0.0022</td>
#       <td id="T_c6206_row11_col1" class="data row11 col1" >0.0036</td>
#       <td id="T_c6206_row11_col2" class="data row11 col2" >0.0085</td>
#       <td id="T_c6206_row11_col3" class="data row11 col3" >0.0007</td>
#       <td id="T_c6206_row11_col4" class="data row11 col4" >0.0018</td>
#       <td id="T_c6206_row11_col5" class="data row11 col5" >0.0015</td>
#     </tr>
#   </tbody>
# </table>
#    algorithm         R2       MAE        MSE      RMSE      MPE(%)
# 0         et   0.995037  0.052871   0.022269  0.149229    2.504567
# 1         rf   0.990831  0.110761   0.041138  0.202825    5.208078
# 2   lightgbm   0.990428  0.129388   0.042949  0.207241    8.232386
# 3         dt   0.976190  0.127065   0.106831  0.326850    5.745034
# 4        gbr   0.948296  0.318303   0.231986  0.481650   22.287095
# 5      ridge   0.803309  0.706022   0.882521  0.939426   81.146627
# 6         lr   0.803307  0.706019   0.882531  0.939431   81.139670
# 7        lar   0.803306  0.706022   0.882535  0.939433   81.140802
# 8         br   0.803298  0.706024   0.882571  0.939453   81.123568
# 9         tr   0.802924  0.701834   0.884249  0.940345   78.495038
# 10        en   0.787626  0.733143   0.952892  0.976162   76.794513
# 11     lasso   0.783576  0.738029   0.971060  0.985424   74.498575
# 12     huber   0.714777  0.824076   1.279754  1.131262   65.572905
# 13       par   0.685832  0.866033   1.409625  1.187276   74.001039
# 14       knn   0.679771  0.840096   1.436819  1.198674   52.280507
# 15       ada   0.637713  1.164905   1.625528  1.274962  130.851257
# 16       ard   0.606441  1.006647   1.765838  1.328848   81.138809
# 17    ransac   0.561340  0.861169   1.968201  1.402926   47.844756
# 18       omp   0.275253  1.345493   3.251829  1.803283  101.885625
# 19      llar  -0.000010  1.664816   4.486893  2.118229  174.728205
# 20       mlp -13.496760  7.434824  65.044746  8.065032  697.755680

# %%
# compare algorithm (tuned case)
# 여러 regression 알고리즘 중 가장 높은 성능을 내는 알고리즘 탐색 (모든 알고리즘 탐색)
# 각각의 algorithm은 auto tune을 이용하여 튜닝

# activate logger
[model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm="lightgbm", frac_ratio=0.9, save_en=False, save_model_name="model", new_feature_names=new_feature_names)


# variable
algorithm_list = models().index
except_list = ["kr","svm","dt"] # algorithm list to exclude from train
result = []


# eleminate algorithm in exception list
for al_name in except_list :

    algorithm_list = algorithm_list[algorithm_list!=al_name]

    
# train each algorithm
for al_name in algorithm_list :

    [model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm=al_name, new_feature_names=new_feature_names)
    tuned_model = tune_model(model, n_iter=100, optimize="MAE", early_stopping=False, choose_better=True, verbose=True)
    [R2, MAE, MSE, RMSE, MPE] = verify_model(tuned_model, data_seen, data_unseen, parameter)
    result.append([al_name, R2, MAE, MSE, RMSE, MPE])


# compare model result
pd.DataFrame(result,columns = ["algorithm","R2","MAE","MSE","RMSE","MPE(%)"]).sort_values(by='R2' ,ascending=False).reset_index(drop=True)
# Out:
# <style type="text/css">
# #T_eca85_row10_col0, #T_eca85_row10_col1, #T_eca85_row10_col2, #T_eca85_row10_col3, #T_eca85_row10_col4, #T_eca85_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eca85_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eca85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eca85_row0_col0" class="data row0 col0" >0.1835</td>
#       <td id="T_eca85_row0_col1" class="data row0 col1" >0.0982</td>
#       <td id="T_eca85_row0_col2" class="data row0 col2" >0.3133</td>
#       <td id="T_eca85_row0_col3" class="data row0 col3" >0.9778</td>
#       <td id="T_eca85_row0_col4" class="data row0 col4" >0.0657</td>
#       <td id="T_eca85_row0_col5" class="data row0 col5" >0.0872</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eca85_row1_col0" class="data row1 col0" >0.1863</td>
#       <td id="T_eca85_row1_col1" class="data row1 col1" >0.0949</td>
#       <td id="T_eca85_row1_col2" class="data row1 col2" >0.3081</td>
#       <td id="T_eca85_row1_col3" class="data row1 col3" >0.9793</td>
#       <td id="T_eca85_row1_col4" class="data row1 col4" >0.0666</td>
#       <td id="T_eca85_row1_col5" class="data row1 col5" >0.0913</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eca85_row2_col0" class="data row2 col0" >0.1864</td>
#       <td id="T_eca85_row2_col1" class="data row2 col1" >0.0924</td>
#       <td id="T_eca85_row2_col2" class="data row2 col2" >0.3040</td>
#       <td id="T_eca85_row2_col3" class="data row2 col3" >0.9791</td>
#       <td id="T_eca85_row2_col4" class="data row2 col4" >0.0649</td>
#       <td id="T_eca85_row2_col5" class="data row2 col5" >0.0889</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eca85_row3_col0" class="data row3 col0" >0.1914</td>
#       <td id="T_eca85_row3_col1" class="data row3 col1" >0.0990</td>
#       <td id="T_eca85_row3_col2" class="data row3 col2" >0.3146</td>
#       <td id="T_eca85_row3_col3" class="data row3 col3" >0.9784</td>
#       <td id="T_eca85_row3_col4" class="data row3 col4" >0.0688</td>
#       <td id="T_eca85_row3_col5" class="data row3 col5" >0.0928</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eca85_row4_col0" class="data row4 col0" >0.1802</td>
#       <td id="T_eca85_row4_col1" class="data row4 col1" >0.0812</td>
#       <td id="T_eca85_row4_col2" class="data row4 col2" >0.2850</td>
#       <td id="T_eca85_row4_col3" class="data row4 col3" >0.9818</td>
#       <td id="T_eca85_row4_col4" class="data row4 col4" >0.0623</td>
#       <td id="T_eca85_row4_col5" class="data row4 col5" >0.0877</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eca85_row5_col0" class="data row5 col0" >0.1838</td>
#       <td id="T_eca85_row5_col1" class="data row5 col1" >0.0896</td>
#       <td id="T_eca85_row5_col2" class="data row5 col2" >0.2993</td>
#       <td id="T_eca85_row5_col3" class="data row5 col3" >0.9799</td>
#       <td id="T_eca85_row5_col4" class="data row5 col4" >0.0660</td>
#       <td id="T_eca85_row5_col5" class="data row5 col5" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eca85_row6_col0" class="data row6 col0" >0.1832</td>
#       <td id="T_eca85_row6_col1" class="data row6 col1" >0.0908</td>
#       <td id="T_eca85_row6_col2" class="data row6 col2" >0.3014</td>
#       <td id="T_eca85_row6_col3" class="data row6 col3" >0.9798</td>
#       <td id="T_eca85_row6_col4" class="data row6 col4" >0.0631</td>
#       <td id="T_eca85_row6_col5" class="data row6 col5" >0.0845</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eca85_row7_col0" class="data row7 col0" >0.1832</td>
#       <td id="T_eca85_row7_col1" class="data row7 col1" >0.0962</td>
#       <td id="T_eca85_row7_col2" class="data row7 col2" >0.3102</td>
#       <td id="T_eca85_row7_col3" class="data row7 col3" >0.9792</td>
#       <td id="T_eca85_row7_col4" class="data row7 col4" >0.0644</td>
#       <td id="T_eca85_row7_col5" class="data row7 col5" >0.0859</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eca85_row8_col0" class="data row8 col0" >0.1878</td>
#       <td id="T_eca85_row8_col1" class="data row8 col1" >0.0984</td>
#       <td id="T_eca85_row8_col2" class="data row8 col2" >0.3136</td>
#       <td id="T_eca85_row8_col3" class="data row8 col3" >0.9783</td>
#       <td id="T_eca85_row8_col4" class="data row8 col4" >0.0672</td>
#       <td id="T_eca85_row8_col5" class="data row8 col5" >0.0896</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eca85_row9_col0" class="data row9 col0" >0.1961</td>
#       <td id="T_eca85_row9_col1" class="data row9 col1" >0.1042</td>
#       <td id="T_eca85_row9_col2" class="data row9 col2" >0.3228</td>
#       <td id="T_eca85_row9_col3" class="data row9 col3" >0.9774</td>
#       <td id="T_eca85_row9_col4" class="data row9 col4" >0.0662</td>
#       <td id="T_eca85_row9_col5" class="data row9 col5" >0.0906</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eca85_row10_col0" class="data row10 col0" >0.1862</td>
#       <td id="T_eca85_row10_col1" class="data row10 col1" >0.0945</td>
#       <td id="T_eca85_row10_col2" class="data row10 col2" >0.3072</td>
#       <td id="T_eca85_row10_col3" class="data row10 col3" >0.9791</td>
#       <td id="T_eca85_row10_col4" class="data row10 col4" >0.0655</td>
#       <td id="T_eca85_row10_col5" class="data row10 col5" >0.0887</td>
#     </tr>
#     <tr>
#       <th id="T_eca85_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_eca85_row11_col0" class="data row11 col0" >0.0044</td>
#       <td id="T_eca85_row11_col1" class="data row11 col1" >0.0060</td>
#       <td id="T_eca85_row11_col2" class="data row11 col2" >0.0099</td>
#       <td id="T_eca85_row11_col3" class="data row11 col3" >0.0012</td>
#       <td id="T_eca85_row11_col4" class="data row11 col4" >0.0018</td>
#       <td id="T_eca85_row11_col5" class="data row11 col5" >0.0024</td>
#     </tr>
#   </tbody>
# </table>
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   20:37:18
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .    Random Forest Regressor
# Empty DataFrame
# Columns: [MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 48 concurrent workers.

# %%
# regression data

## - opt
# algorithm : regression algorithm (default : "ligthgbm")
# frac_ratio : train set / test set ratio (default : 0.9)
# silent : (default : True)
# save_en : whether to save the trained model as a file (.pkl) : (default : False)
# save_model_name : model file name : (default : "model")
# new_feature_names : to avoid number of features error (default : [])

## - algorithm list (see detail : https://pycaret.readthedocs.io/en/latest/api/regression.html)
# 'lr' - Linear Regression
# 'lasso' - Lasso Regression
# 'ridge' - Ridge Regression
# 'en' - Elastic Net
# 'lar' - Least Angle Regression
# 'llar' - Lasso Least Angle Regression
# 'omp' - Orthogonal Matching Pursuit
# 'br' - Bayesian Ridge
# 'ard' - Automatic Relevance Determination
# 'par' - Passive Aggressive Regressor
# 'ransac' - Random Sample Consensus
# 'tr' - TheilSen Regressor
# 'huber' - Huber Regressor
# 'kr' - Kernel Ridge
# 'svm' - Support Vector Regression
# 'knn' - K Neighbors Regressor
# 'dt' - Decision Tree Regressor
# 'rf' - Random Forest Regressor
# 'et' - Extra Trees Regressor
# 'ada' - AdaBoost Regressor
# 'gbr' - Gradient Boosting Regressor
# 'mlp' - MLP Regressor
# 'xgboost' - Extreme Gradient Boosting
# 'lightgbm' - Light Gradient Boosting Machine
# 'catboost' - CatBoost Regressor


[model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm="lightgbm", frac_ratio=0.9, save_en=False, save_model_name="model", new_feature_names=new_feature_names)
# Out:
# <style type="text/css">
# #T_60bee_row10_col0, #T_60bee_row10_col1, #T_60bee_row10_col2, #T_60bee_row10_col3, #T_60bee_row10_col4, #T_60bee_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_60bee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60bee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60bee_row0_col0" class="data row0 col0" >0.1339</td>
#       <td id="T_60bee_row0_col1" class="data row0 col1" >0.0488</td>
#       <td id="T_60bee_row0_col2" class="data row0 col2" >0.2210</td>
#       <td id="T_60bee_row0_col3" class="data row0 col3" >0.9890</td>
#       <td id="T_60bee_row0_col4" class="data row0 col4" >0.0547</td>
#       <td id="T_60bee_row0_col5" class="data row0 col5" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60bee_row1_col0" class="data row1 col0" >0.1360</td>
#       <td id="T_60bee_row1_col1" class="data row1 col1" >0.0483</td>
#       <td id="T_60bee_row1_col2" class="data row1 col2" >0.2198</td>
#       <td id="T_60bee_row1_col3" class="data row1 col3" >0.9894</td>
#       <td id="T_60bee_row1_col4" class="data row1 col4" >0.0562</td>
#       <td id="T_60bee_row1_col5" class="data row1 col5" >0.0896</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_60bee_row2_col0" class="data row2 col0" >0.1346</td>
#       <td id="T_60bee_row2_col1" class="data row2 col1" >0.0433</td>
#       <td id="T_60bee_row2_col2" class="data row2 col2" >0.2080</td>
#       <td id="T_60bee_row2_col3" class="data row2 col3" >0.9902</td>
#       <td id="T_60bee_row2_col4" class="data row2 col4" >0.0541</td>
#       <td id="T_60bee_row2_col5" class="data row2 col5" >0.0867</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60bee_row3_col0" class="data row3 col0" >0.1371</td>
#       <td id="T_60bee_row3_col1" class="data row3 col1" >0.0488</td>
#       <td id="T_60bee_row3_col2" class="data row3 col2" >0.2209</td>
#       <td id="T_60bee_row3_col3" class="data row3 col3" >0.9893</td>
#       <td id="T_60bee_row3_col4" class="data row3 col4" >0.0567</td>
#       <td id="T_60bee_row3_col5" class="data row3 col5" >0.0855</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_60bee_row4_col0" class="data row4 col0" >0.1357</td>
#       <td id="T_60bee_row4_col1" class="data row4 col1" >0.0393</td>
#       <td id="T_60bee_row4_col2" class="data row4 col2" >0.1982</td>
#       <td id="T_60bee_row4_col3" class="data row4 col3" >0.9912</td>
#       <td id="T_60bee_row4_col4" class="data row4 col4" >0.0516</td>
#       <td id="T_60bee_row4_col5" class="data row4 col5" >0.0859</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_60bee_row5_col0" class="data row5 col0" >0.1361</td>
#       <td id="T_60bee_row5_col1" class="data row5 col1" >0.0416</td>
#       <td id="T_60bee_row5_col2" class="data row5 col2" >0.2038</td>
#       <td id="T_60bee_row5_col3" class="data row5 col3" >0.9907</td>
#       <td id="T_60bee_row5_col4" class="data row5 col4" >0.0563</td>
#       <td id="T_60bee_row5_col5" class="data row5 col5" >0.0895</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_60bee_row6_col0" class="data row6 col0" >0.1387</td>
#       <td id="T_60bee_row6_col1" class="data row6 col1" >0.0455</td>
#       <td id="T_60bee_row6_col2" class="data row6 col2" >0.2133</td>
#       <td id="T_60bee_row6_col3" class="data row6 col3" >0.9899</td>
#       <td id="T_60bee_row6_col4" class="data row6 col4" >0.0534</td>
#       <td id="T_60bee_row6_col5" class="data row6 col5" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_60bee_row7_col0" class="data row7 col0" >0.1414</td>
#       <td id="T_60bee_row7_col1" class="data row7 col1" >0.0504</td>
#       <td id="T_60bee_row7_col2" class="data row7 col2" >0.2246</td>
#       <td id="T_60bee_row7_col3" class="data row7 col3" >0.9891</td>
#       <td id="T_60bee_row7_col4" class="data row7 col4" >0.0562</td>
#       <td id="T_60bee_row7_col5" class="data row7 col5" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_60bee_row8_col0" class="data row8 col0" >0.1381</td>
#       <td id="T_60bee_row8_col1" class="data row8 col1" >0.0497</td>
#       <td id="T_60bee_row8_col2" class="data row8 col2" >0.2229</td>
#       <td id="T_60bee_row8_col3" class="data row8 col3" >0.9890</td>
#       <td id="T_60bee_row8_col4" class="data row8 col4" >0.0555</td>
#       <td id="T_60bee_row8_col5" class="data row8 col5" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_60bee_row9_col0" class="data row9 col0" >0.1390</td>
#       <td id="T_60bee_row9_col1" class="data row9 col1" >0.0442</td>
#       <td id="T_60bee_row9_col2" class="data row9 col2" >0.2102</td>
#       <td id="T_60bee_row9_col3" class="data row9 col3" >0.9904</td>
#       <td id="T_60bee_row9_col4" class="data row9 col4" >0.0520</td>
#       <td id="T_60bee_row9_col5" class="data row9 col5" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_60bee_row10_col0" class="data row10 col0" >0.1371</td>
#       <td id="T_60bee_row10_col1" class="data row10 col1" >0.0460</td>
#       <td id="T_60bee_row10_col2" class="data row10 col2" >0.2143</td>
#       <td id="T_60bee_row10_col3" class="data row10 col3" >0.9898</td>
#       <td id="T_60bee_row10_col4" class="data row10 col4" >0.0547</td>
#       <td id="T_60bee_row10_col5" class="data row10 col5" >0.0869</td>
#     </tr>
#     <tr>
#       <th id="T_60bee_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_60bee_row11_col0" class="data row11 col0" >0.0022</td>
#       <td id="T_60bee_row11_col1" class="data row11 col1" >0.0036</td>
#       <td id="T_60bee_row11_col2" class="data row11 col2" >0.0085</td>
#       <td id="T_60bee_row11_col3" class="data row11 col3" >0.0007</td>
#       <td id="T_60bee_row11_col4" class="data row11 col4" >0.0018</td>
#       <td id="T_60bee_row11_col5" class="data row11 col5" >0.0015</td>
#     </tr>
#   </tbody>
# </table>

# %%
# verify model

verify_model(model, data_seen, data_unseen, parameter)
# Out:
# array([0.99042782, 0.12938798, 0.0429489 , 0.20724116, 8.23238559])

# %%
# tune model

tune_model(model, n_iter=10, optimize="R2", early_stopping=False, verbose=True)
# Out:
# <style type="text/css">
# #T_3ddc3_row10_col0, #T_3ddc3_row10_col1, #T_3ddc3_row10_col2, #T_3ddc3_row10_col3, #T_3ddc3_row10_col4, #T_3ddc3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3ddc3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ddc3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ddc3_row0_col0" class="data row0 col0" >0.1649</td>
#       <td id="T_3ddc3_row0_col1" class="data row0 col1" >0.0764</td>
#       <td id="T_3ddc3_row0_col2" class="data row0 col2" >0.2764</td>
#       <td id="T_3ddc3_row0_col3" class="data row0 col3" >0.9827</td>
#       <td id="T_3ddc3_row0_col4" class="data row0 col4" >0.0664</td>
#       <td id="T_3ddc3_row0_col5" class="data row0 col5" >0.1094</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ddc3_row1_col0" class="data row1 col0" >0.1663</td>
#       <td id="T_3ddc3_row1_col1" class="data row1 col1" >0.0760</td>
#       <td id="T_3ddc3_row1_col2" class="data row1 col2" >0.2757</td>
#       <td id="T_3ddc3_row1_col3" class="data row1 col3" >0.9834</td>
#       <td id="T_3ddc3_row1_col4" class="data row1 col4" >0.0670</td>
#       <td id="T_3ddc3_row1_col5" class="data row1 col5" >0.1141</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ddc3_row2_col0" class="data row2 col0" >0.1606</td>
#       <td id="T_3ddc3_row2_col1" class="data row2 col1" >0.0690</td>
#       <td id="T_3ddc3_row2_col2" class="data row2 col2" >0.2626</td>
#       <td id="T_3ddc3_row2_col3" class="data row2 col3" >0.9844</td>
#       <td id="T_3ddc3_row2_col4" class="data row2 col4" >0.0642</td>
#       <td id="T_3ddc3_row2_col5" class="data row2 col5" >0.1043</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3ddc3_row3_col0" class="data row3 col0" >0.1671</td>
#       <td id="T_3ddc3_row3_col1" class="data row3 col1" >0.0750</td>
#       <td id="T_3ddc3_row3_col2" class="data row3 col2" >0.2738</td>
#       <td id="T_3ddc3_row3_col3" class="data row3 col3" >0.9836</td>
#       <td id="T_3ddc3_row3_col4" class="data row3 col4" >0.0668</td>
#       <td id="T_3ddc3_row3_col5" class="data row3 col5" >0.1090</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3ddc3_row4_col0" class="data row4 col0" >0.1572</td>
#       <td id="T_3ddc3_row4_col1" class="data row4 col1" >0.0618</td>
#       <td id="T_3ddc3_row4_col2" class="data row4 col2" >0.2485</td>
#       <td id="T_3ddc3_row4_col3" class="data row4 col3" >0.9862</td>
#       <td id="T_3ddc3_row4_col4" class="data row4 col4" >0.0600</td>
#       <td id="T_3ddc3_row4_col5" class="data row4 col5" >0.1022</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3ddc3_row5_col0" class="data row5 col0" >0.1652</td>
#       <td id="T_3ddc3_row5_col1" class="data row5 col1" >0.0669</td>
#       <td id="T_3ddc3_row5_col2" class="data row5 col2" >0.2587</td>
#       <td id="T_3ddc3_row5_col3" class="data row5 col3" >0.9850</td>
#       <td id="T_3ddc3_row5_col4" class="data row5 col4" >0.0670</td>
#       <td id="T_3ddc3_row5_col5" class="data row5 col5" >0.1095</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3ddc3_row6_col0" class="data row6 col0" >0.1630</td>
#       <td id="T_3ddc3_row6_col1" class="data row6 col1" >0.0713</td>
#       <td id="T_3ddc3_row6_col2" class="data row6 col2" >0.2670</td>
#       <td id="T_3ddc3_row6_col3" class="data row6 col3" >0.9841</td>
#       <td id="T_3ddc3_row6_col4" class="data row6 col4" >0.0631</td>
#       <td id="T_3ddc3_row6_col5" class="data row6 col5" >0.1037</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3ddc3_row7_col0" class="data row7 col0" >0.1631</td>
#       <td id="T_3ddc3_row7_col1" class="data row7 col1" >0.0756</td>
#       <td id="T_3ddc3_row7_col2" class="data row7 col2" >0.2750</td>
#       <td id="T_3ddc3_row7_col3" class="data row7 col3" >0.9837</td>
#       <td id="T_3ddc3_row7_col4" class="data row7 col4" >0.0640</td>
#       <td id="T_3ddc3_row7_col5" class="data row7 col5" >0.1045</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3ddc3_row8_col0" class="data row8 col0" >0.1688</td>
#       <td id="T_3ddc3_row8_col1" class="data row8 col1" >0.0774</td>
#       <td id="T_3ddc3_row8_col2" class="data row8 col2" >0.2783</td>
#       <td id="T_3ddc3_row8_col3" class="data row8 col3" >0.9829</td>
#       <td id="T_3ddc3_row8_col4" class="data row8 col4" >0.0678</td>
#       <td id="T_3ddc3_row8_col5" class="data row8 col5" >0.1099</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3ddc3_row9_col0" class="data row9 col0" >0.1679</td>
#       <td id="T_3ddc3_row9_col1" class="data row9 col1" >0.0756</td>
#       <td id="T_3ddc3_row9_col2" class="data row9 col2" >0.2749</td>
#       <td id="T_3ddc3_row9_col3" class="data row9 col3" >0.9836</td>
#       <td id="T_3ddc3_row9_col4" class="data row9 col4" >0.0632</td>
#       <td id="T_3ddc3_row9_col5" class="data row9 col5" >0.1038</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3ddc3_row10_col0" class="data row10 col0" >0.1644</td>
#       <td id="T_3ddc3_row10_col1" class="data row10 col1" >0.0725</td>
#       <td id="T_3ddc3_row10_col2" class="data row10 col2" >0.2691</td>
#       <td id="T_3ddc3_row10_col3" class="data row10 col3" >0.9840</td>
#       <td id="T_3ddc3_row10_col4" class="data row10 col4" >0.0650</td>
#       <td id="T_3ddc3_row10_col5" class="data row10 col5" >0.1070</td>
#     </tr>
#     <tr>
#       <th id="T_3ddc3_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_3ddc3_row11_col0" class="data row11 col0" >0.0034</td>
#       <td id="T_3ddc3_row11_col1" class="data row11 col1" >0.0049</td>
#       <td id="T_3ddc3_row11_col2" class="data row11 col2" >0.0092</td>
#       <td id="T_3ddc3_row11_col3" class="data row11 col3" >0.0010</td>
#       <td id="T_3ddc3_row11_col4" class="data row11 col4" >0.0023</td>
#       <td id="T_3ddc3_row11_col5" class="data row11 col5" >0.0036</td>
#     </tr>
#   </tbody>
# </table>
# LGBMRegressor(bagging_fraction=0.7, bagging_freq=6, boosting_type='gbdt',
#               class_weight=None, colsample_bytree=1.0, feature_fraction=0.5,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=66, min_child_weight=0.001, min_split_gain=0.4,
#               n_estimators=90, n_jobs=-1, num_leaves=90, objective=None,
#               random_state=123, reg_alpha=0.0005, reg_lambda=0.1, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
algorithm_list = models().index

algorithm_list[algorithm_list!="lr"]
# Out:
# Index(['lasso', 'ridge', 'en', 'lar', 'llar', 'omp', 'br', 'ard', 'par',
#        'ransac', 'tr', 'huber', 'kr', 'svm', 'knn', 'dt', 'rf', 'et', 'ada',
#        'gbr', 'mlp', 'lightgbm'],
#       dtype='object', name='ID')

# %%
# compare algorithm (tuned case)
# 여러 regression 알고리즘 중 가장 높은 성능을 내는 알고리즘 탐색 (모든 알고리즘 탐색)
# 각각의 algorithm은 auto tune을 이용하여 튜닝

# activate logger
[model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm="lightgbm", frac_ratio=0.9, save_en=False, save_model_name="model", new_feature_names=new_feature_names)


# variable
algorithm_list = models().index
except_list = ["kr","svm","huber","rf","et"] # algorithm list to exclude from train
result = []


# eleminate algorithm in exception list
for al_name in except_list :

    algorithm_list = algorithm_list[algorithm_list!=al_name]

algorithm_list = ["lightgbm"]
    
# train each algorithm
for al_name in algorithm_list :

    start_time = time.time()

    [model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm=al_name, new_feature_names=new_feature_names, use_gpu=False, n_jobs=47)
    print(f'{al_name} : {datetime.now()}')
    # tuned_model = tune_model(model, n_iter=1000, optimize="MAE", early_stopping=False, choose_better=True, verbose=True, search_library="tune-sklearn", search_algorithm="random")
    tuned_model = tune_model(model, n_iter=3000, optimize="MAE", early_stopping=False, choose_better=True, verbose=True)
    [R2, MAE, MSE, RMSE, MPE] = verify_model(tuned_model, data_seen, data_unseen, parameter)

    end_time= time.time()
    timetime = end_time - start_time

    result.append([al_name, R2, MAE, MSE, RMSE, MPE, timetime])


# compare model result
pd.DataFrame(result,columns = ["algorithm","R2","MAE","MSE","RMSE","MPE(%)","time(s)"]).sort_values(by='R2' ,ascending=False).reset_index(drop=True)
# Out:
# <style type="text/css">
# #T_85c90_row10_col0, #T_85c90_row10_col1, #T_85c90_row10_col2, #T_85c90_row10_col3, #T_85c90_row10_col4, #T_85c90_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_85c90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85c90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85c90_row0_col0" class="data row0 col0" >0.7227</td>
#       <td id="T_85c90_row0_col1" class="data row0 col1" >1.1163</td>
#       <td id="T_85c90_row0_col2" class="data row0 col2" >1.0566</td>
#       <td id="T_85c90_row0_col3" class="data row0 col3" >0.9788</td>
#       <td id="T_85c90_row0_col4" class="data row0 col4" >0.0743</td>
#       <td id="T_85c90_row0_col5" class="data row0 col5" >0.0632</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85c90_row1_col0" class="data row1 col0" >0.7299</td>
#       <td id="T_85c90_row1_col1" class="data row1 col1" >1.1384</td>
#       <td id="T_85c90_row1_col2" class="data row1 col2" >1.0669</td>
#       <td id="T_85c90_row1_col3" class="data row1 col3" >0.9785</td>
#       <td id="T_85c90_row1_col4" class="data row1 col4" >0.0715</td>
#       <td id="T_85c90_row1_col5" class="data row1 col5" >0.0611</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85c90_row2_col0" class="data row2 col0" >0.7380</td>
#       <td id="T_85c90_row2_col1" class="data row2 col1" >1.1633</td>
#       <td id="T_85c90_row2_col2" class="data row2 col2" >1.0785</td>
#       <td id="T_85c90_row2_col3" class="data row2 col3" >0.9788</td>
#       <td id="T_85c90_row2_col4" class="data row2 col4" >0.0730</td>
#       <td id="T_85c90_row2_col5" class="data row2 col5" >0.0621</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85c90_row3_col0" class="data row3 col0" >0.7279</td>
#       <td id="T_85c90_row3_col1" class="data row3 col1" >1.1925</td>
#       <td id="T_85c90_row3_col2" class="data row3 col2" >1.0920</td>
#       <td id="T_85c90_row3_col3" class="data row3 col3" >0.9766</td>
#       <td id="T_85c90_row3_col4" class="data row3 col4" >0.0754</td>
#       <td id="T_85c90_row3_col5" class="data row3 col5" >0.0633</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85c90_row4_col0" class="data row4 col0" >0.7335</td>
#       <td id="T_85c90_row4_col1" class="data row4 col1" >1.1579</td>
#       <td id="T_85c90_row4_col2" class="data row4 col2" >1.0761</td>
#       <td id="T_85c90_row4_col3" class="data row4 col3" >0.9778</td>
#       <td id="T_85c90_row4_col4" class="data row4 col4" >0.0724</td>
#       <td id="T_85c90_row4_col5" class="data row4 col5" >0.0615</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85c90_row5_col0" class="data row5 col0" >0.7364</td>
#       <td id="T_85c90_row5_col1" class="data row5 col1" >1.2226</td>
#       <td id="T_85c90_row5_col2" class="data row5 col2" >1.1057</td>
#       <td id="T_85c90_row5_col3" class="data row5 col3" >0.9764</td>
#       <td id="T_85c90_row5_col4" class="data row5 col4" >0.0731</td>
#       <td id="T_85c90_row5_col5" class="data row5 col5" >0.0619</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_85c90_row6_col0" class="data row6 col0" >0.7259</td>
#       <td id="T_85c90_row6_col1" class="data row6 col1" >1.1502</td>
#       <td id="T_85c90_row6_col2" class="data row6 col2" >1.0725</td>
#       <td id="T_85c90_row6_col3" class="data row6 col3" >0.9783</td>
#       <td id="T_85c90_row6_col4" class="data row6 col4" >0.0744</td>
#       <td id="T_85c90_row6_col5" class="data row6 col5" >0.0623</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_85c90_row7_col0" class="data row7 col0" >0.7321</td>
#       <td id="T_85c90_row7_col1" class="data row7 col1" >1.1340</td>
#       <td id="T_85c90_row7_col2" class="data row7 col2" >1.0649</td>
#       <td id="T_85c90_row7_col3" class="data row7 col3" >0.9781</td>
#       <td id="T_85c90_row7_col4" class="data row7 col4" >0.0745</td>
#       <td id="T_85c90_row7_col5" class="data row7 col5" >0.0634</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_85c90_row8_col0" class="data row8 col0" >0.7266</td>
#       <td id="T_85c90_row8_col1" class="data row8 col1" >1.2335</td>
#       <td id="T_85c90_row8_col2" class="data row8 col2" >1.1106</td>
#       <td id="T_85c90_row8_col3" class="data row8 col3" >0.9764</td>
#       <td id="T_85c90_row8_col4" class="data row8 col4" >0.0760</td>
#       <td id="T_85c90_row8_col5" class="data row8 col5" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_85c90_row9_col0" class="data row9 col0" >0.7114</td>
#       <td id="T_85c90_row9_col1" class="data row9 col1" >1.1359</td>
#       <td id="T_85c90_row9_col2" class="data row9 col2" >1.0658</td>
#       <td id="T_85c90_row9_col3" class="data row9 col3" >0.9791</td>
#       <td id="T_85c90_row9_col4" class="data row9 col4" >0.0722</td>
#       <td id="T_85c90_row9_col5" class="data row9 col5" >0.0608</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_85c90_row10_col0" class="data row10 col0" >0.7284</td>
#       <td id="T_85c90_row10_col1" class="data row10 col1" >1.1645</td>
#       <td id="T_85c90_row10_col2" class="data row10 col2" >1.0790</td>
#       <td id="T_85c90_row10_col3" class="data row10 col3" >0.9779</td>
#       <td id="T_85c90_row10_col4" class="data row10 col4" >0.0737</td>
#       <td id="T_85c90_row10_col5" class="data row10 col5" >0.0623</td>
#     </tr>
#     <tr>
#       <th id="T_85c90_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_85c90_row11_col0" class="data row11 col0" >0.0073</td>
#       <td id="T_85c90_row11_col1" class="data row11 col1" >0.0373</td>
#       <td id="T_85c90_row11_col2" class="data row11 col2" >0.0172</td>
#       <td id="T_85c90_row11_col3" class="data row11 col3" >0.0010</td>
#       <td id="T_85c90_row11_col4" class="data row11 col4" >0.0014</td>
#       <td id="T_85c90_row11_col5" class="data row11 col5" >0.0009</td>
#     </tr>
#   </tbody>
# </table>
# lightgbm : 2022-01-12 20:35:18.557176
# IntProgress(value=0, description='Processing: ', max=7)
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         20:35:18
# Status           Searching Hyperparameters
# Estimator  Light Gradient Boosting Machine
# Empty DataFrame
# Columns: [MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []
# Fitting 10 folds for each of 3000 candidates, totalling 30000 fits
# [Parallel(n_jobs=47)]: Using backend LokyBackend with 47 concurrent workers.
# [Parallel(n_jobs=47)]: Done 106 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=47)]: Done 356 tasks      | elapsed:   58.1s
# [Parallel(n_jobs=47)]: Done 706 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=47)]: Done 1156 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=47)]: Done 1706 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=47)]: Done 2356 tasks      | elapsed:  6.4min

# %%
# compare algorithm (tuned case)
# 여러 regression 알고리즘 중 가장 높은 성능을 내는 알고리즘 탐색 (모든 알고리즘 탐색)
# 각각의 algorithm은 auto tune을 이용하여 튜닝

# activate logger
[model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm="lightgbm", frac_ratio=0.9, save_en=False, save_model_name="model", new_feature_names=new_feature_names)


# variable
algorithm_list = models().index
except_list = ["kr","svm","huber","rf","et"] # algorithm list to exclude from train
result = []


# eleminate algorithm in exception list
for al_name in except_list :

    algorithm_list = algorithm_list[algorithm_list!=al_name]

algorithm_list = ["lightgbm"]
    
# train each algorithm
for al_name in algorithm_list :

    start_time = time.time()

    [model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm=al_name, new_feature_names=new_feature_names)
    print(f'{al_name}')
    tuned_model = tune_model(model, n_iter=3000, optimize="MAE", early_stopping=False, choose_better=True, verbose=True, search_library="tune-sklearn", search_algorithm="bayesian")
    [R2, MAE, MSE, RMSE, MPE] = verify_model(tuned_model, data_seen, data_unseen, parameter)

    end_time= time.time()
    timetime = end_time - start_time

    result.append([al_name, R2, MAE, MSE, RMSE, MPE, timetime])


# compare model result
pd.DataFrame(result,columns = ["algorithm","R2","MAE","MSE","RMSE","MPE(%)","time(s)"]).sort_values(by='R2' ,ascending=False).reset_index(drop=True)
# Out:
# == Status ==<br>Current time: 2022-01-12 21:06:21 (running for 00:18:24.84)<br>Memory usage on this node: 74.6/255.9 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 47.0/48 CPUs, 0/1 GPUs, 0.0/126.14 GiB heap, 0.0/58.05 GiB objects<br>Result logdir: C:\Users\user\ray_results\_Trainable_2022-01-12_20-47-55<br>Number of trials: 353/3000 (1 PENDING, 47 RUNNING, 305 TERMINATED)<br><br>
#  pid=30776) [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
#  pid=30776) [LightGBM] [Warning] bagging_fraction is set=0.8128533982672117, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8128533982672117
#  pid=30776) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#  pid=33592) [LightGBM] [Warning] feature_fraction is set=0.6344082904248483, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6344082904248483
#  pid=33592) [LightGBM] [Warning] bagging_fraction is set=0.4, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4
#  pid=33592) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#  pid=21400) [LightGBM] [Warning] feature_fraction is set=0.6810941675621649, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6810941675621649
#  pid=21400) [LightGBM] [Warning] bagging_fraction is set=0.542767529811697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.542767529811697
#  pid=21400) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#  pid=30776) [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
#  pid=30776) [LightGBM] [Warning] bagging_fraction is set=0.8128533982672117, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8128533982672117
#  pid=30776) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#  pid=33592) [LightGBM] [Warning] feature_fraction is set=0.6344082904248483, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6344082904248483
#  pid=33592) [LightGBM] [Warning] bagging_fraction is set=0.4, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4
#  pid=33592) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#  pid=30776) [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
#  pid=30776) [LightGBM] [Warning] bagging_fraction is set=0.8128533982672117, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8128533982672117
#  pid=30776) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#  pid=21400) [LightGBM] [Warning] feature_fraction is set=0.6810941675621649, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6810941675621649
#  pid=21400) [LightGBM] [Warning] bagging_fraction is set=0.542767529811697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.542767529811697
#  pid=21400) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#  pid=33592) [LightGBM] [Warning] feature_fraction is set=0.6344082904248483, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6344082904248483
#  pid=33592) [LightGBM] [Warning] bagging_fraction is set=0.4, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4
#  pid=33592) [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# The `process_trial_result` operation took 8.810 s, which may be a performance bottleneck.
# Processing trial results took 8.811 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# The `process_trial` operation took 8.812 s, which may be a performance bottleneck.
# == Status ==<br>Current time: 2022-01-12 21:06:30 (running for 00:18:33.69)<br>Memory usage on this node: 74.5/255.9 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 47.0/48 CPUs, 0/1 GPUs, 0.0/126.14 GiB heap, 0.0/58.05 GiB objects<br>Result logdir: C:\Users\user\ray_results\_Trainable_2022-01-12_20-47-55<br>Number of trials: 354/3000 (1 PENDING, 47 RUNNING, 306 TERMINATED)<br><br>

# %%
# compare algorithm (tuned case)
# 여러 regression 알고리즘 중 가장 높은 성능을 내는 알고리즘 탐색 (모든 알고리즘 탐색)
# 각각의 algorithm은 auto tune을 이용하여 튜닝

# activate logger
[model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm="lightgbm", frac_ratio=0.9, save_en=False, save_model_name="model", new_feature_names=new_feature_names)


# variable
algorithm_list = models().index
except_list = ["kr","svm","huber","rf","et"] # algorithm list to exclude from train
result = []


# eleminate algorithm in exception list
for al_name in except_list :

    algorithm_list = algorithm_list[algorithm_list!=al_name]

algorithm_list = ["lightgbm"]
    
# train each algorithm
for al_name in algorithm_list :

    start_time = time.time()

    [model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm=al_name, new_feature_names=new_feature_names)
    print(f'{al_name}')
    tuned_model = tune_model(model, n_iter=3000, optimize="MAE", early_stopping=False, choose_better=True, verbose=True, search_library="tune-sklearn", search_algorithm="hyperopt")
    [R2, MAE, MSE, RMSE, MPE] = verify_model(tuned_model, data_seen, data_unseen, parameter)

    end_time= time.time()
    timetime = end_time - start_time

    result.append([al_name, R2, MAE, MSE, RMSE, MPE, timetime])


# compare model result
pd.DataFrame(result,columns = ["algorithm","R2","MAE","MSE","RMSE","MPE(%)","time(s)"]).sort_values(by='R2' ,ascending=False).reset_index(drop=True)
# Out:
# == Status ==<br>Current time: 2022-01-12 20:46:23 (running for 00:00:19.90)<br>Memory usage on this node: 65.8/255.9 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 32.0/48 CPUs, 0/1 GPUs, 0.0/129.64 GiB heap, 0.0/59.55 GiB objects<br>Result logdir: C:\Users\user\ray_results\_Trainable_2022-01-12_20-46-03<br>Number of trials: 32/3000 (32 RUNNING)<br><br>
#  pid=31436) [LightGBM] [Warning] feature_fraction is set=0.9933524126635017, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9933524126635017
#  pid=31436) [LightGBM] [Warning] bagging_fraction is set=0.564384572527489, subsample=1.0 will be ignored. Current value: bagging_fraction=0.564384572527489
#  pid=31436) [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
#  pid=31064) [LightGBM] [Warning] feature_fraction is set=0.4059286408496222, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4059286408496222
#  pid=31064) [LightGBM] [Warning] bagging_fraction is set=0.9852046026198501, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9852046026198501
#  pid=31064) [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#  pid=31364) [LightGBM] [Warning] feature_fraction is set=0.6682470001755085, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6682470001755085
#  pid=31364) [LightGBM] [Warning] bagging_fraction is set=0.7078750819469858, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7078750819469858
#  pid=31364) [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
#  pid=31352) [LightGBM] [Warning] feature_fraction is set=0.8297913281561928, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8297913281561928
#  pid=31352) [LightGBM] [Warning] bagging_fraction is set=0.42505265289282834, subsample=1.0 will be ignored. Current value: bagging_fraction=0.42505265289282834
#  pid=31352) [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#  pid=31116) [LightGBM] [Warning] feature_fraction is set=0.698474438268553, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.698474438268553
#  pid=31116) [LightGBM] [Warning] bagging_fraction is set=0.9314073137835901, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9314073137835901
#  pid=31116) [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
#  pid=31024) [LightGBM] [Warning] feature_fraction is set=0.5879608989946455, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5879608989946455
#  pid=31024) [LightGBM] [Warning] bagging_fraction is set=0.8586056956731415, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8586056956731415
#  pid=31024) [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
#  pid=30784) [LightGBM] [Warning] feature_fraction is set=0.7888725069957967, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7888725069957967
#  pid=30784) [LightGBM] [Warning] bagging_fraction is set=0.9918584366204902, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9918584366204902
#  pid=30784) [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# Trials did not complete: [_Trainable_38a23d6f, _Trainable_38c86545, _Trainable_38dadce2, _Trainable_38ee8d13, _Trainable_3901c815, _Trainable_3915512a, _Trainable_39288c39, _Trainable_393c3c69, _Trainable_394fec9d, _Trainable_396375af, _Trainable_3976fee0, _Trainable_398aaf0c, _Trainable_399dea06, _Trainable_39b19a37, _Trainable_39c4fc50, _Trainable_39d85e64, _Trainable_39ebe775, _Trainable_39ff70a0, _Trainable_3a12ab93, _Trainable_3a28099d, _Trainable_3a4c83a9, _Trainable_3a6479df, _Trainable_3a7a9b26, _Trainable_3a90956b, _Trainable_3ab75997, _Trainable_3ade44ba, _Trainable_3af43f00, _Trainable_3b1b2a3e, _Trainable_3b421563, _Trainable_3b5a80cb, _Trainable_3b729e1b, _Trainable_3b8abb54]
# Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30080/1295335549.py in <module>
#      27     [model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm=al_name, new_feature_names=new_feature_names)
#      28     print(f'{al_name}')
# ---> 29     tuned_model = tune_model(model, n_iter=3000, optimize="MAE", early_stopping=False, choose_better=True, verbose=True, search_library="tune-sklearn", search_algorithm="hyperopt")
#      30     [R2, MAE, MSE, RMSE, MPE] = verify_model(tuned_model, data_seen, data_unseen, parameter)
#      31
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\pycaret\regression.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, **kwargs)
#    1083     """
#    1084
# -> 1085     return pycaret.internal.tabular.tune_model_supervised(
#    1086         estimator=estimator,
#    1087         fold=fold,
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\pycaret\internal\tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, **kwargs)
#    4494                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4495         else:
# -> 4496             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4497         best_params = model_grid.best_params_
#    4498         logger.info(f"best_params: {best_params}")
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\tune_sklearn\tune_basesearch.py in fit(self, X, y, groups, tune_params, **fit_params)
#     663             ray_kwargs["local_mode"] = True
#     664         with ray_context(**ray_kwargs):
# --> 665             return self._fit(X, y, groups, tune_params, **fit_params)
#     666
#     667     def score(self, X, y=None):
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\tune_sklearn\tune_basesearch.py in _fit(self, X, y, groups, tune_params, **fit_params)
#     570         analysis = self._tune_run(config, resources_per_trial, tune_params)
#     571
# --> 572         self.cv_results_ = self._format_results(self.n_splits, analysis)
#     573
#     574         metric = self._metric_name
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\tune_sklearn\tune_basesearch.py in _format_results(self, n_splits, out)
#     877
#     878         for name in self.scoring:
# --> 879             _store(
#     880                 results,
#     881                 "test_%s" % name,
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\tune_sklearn\tune_basesearch.py in _store(results, key_name, array, n_splits, n_candidates, weights, splits, rank)
#     862                                             key_name)] = array[:, split_i]
#     863
# --> 864             array_means = np.average(array, axis=1, weights=weights)
#     865             results["mean_%s" % key_name] = array_means
#     866             # Weighted std is not directly available in numpy
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\anaconda3\envs\NEC_stable\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     379     if weights is None:
#     380         avg = a.mean(axis)
# --> 381         scl = avg.dtype.type(a.size/avg.size)
#     382     else:
#     383         wgt = np.asanyarray(weights)
#
# ZeroDivisionError: division by zero

# %%
# compare algorithm (tuned case)
# 여러 regression 알고리즘 중 가장 높은 성능을 내는 알고리즘 탐색 (모든 알고리즘 탐색)
# 각각의 algorithm은 auto tune을 이용하여 튜닝

# activate logger
[model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm="lightgbm", frac_ratio=0.9, save_en=False, save_model_name="model", new_feature_names=new_feature_names)


# variable
algorithm_list = models().index
except_list = ["kr","svm","huber","rf","et"] # algorithm list to exclude from train
result = []


# eleminate algorithm in exception list
for al_name in except_list :

    algorithm_list = algorithm_list[algorithm_list!=al_name]

algorithm_list = ["lightgbm"]
    
# train each algorithm
for al_name in algorithm_list :

    start_time = time.time()

    [model, data_seen, data_unseen] = regression_basic(processed_data, parameter, algorithm=al_name, new_feature_names=new_feature_names)
    print(f'{al_name}')
    tuned_model = tune_model(model, n_iter=3000, optimize="MAE", early_stopping=False, choose_better=True, verbose=True, search_library="tune-sklearn", search_algorithm="optuna")
    [R2, MAE, MSE, RMSE, MPE] = verify_model(tuned_model, data_seen, data_unseen, parameter)

    end_time= time.time()
    timetime = end_time - start_time

    result.append([al_name, R2, MAE, MSE, RMSE, MPE, timetime])


# compare model result
pd.DataFrame(result,columns = ["algorithm","R2","MAE","MSE","RMSE","MPE(%)","time(s)"]).sort_values(by='R2' ,ascending=False).reset_index(drop=True)
# Out:
# == Status ==<br>Current time: 2022-01-12 20:46:54 (running for 00:00:00.13)<br>Memory usage on this node: 61.7/255.9 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/48 CPUs, 0/1 GPUs, 0.0/128.55 GiB heap, 0.0/59.08 GiB objects<br>Result logdir: C:\Users\user\ray_results\_Trainable_2022-01-12_20-46-54<br>Number of trials: 1/3000 (1 PENDING)<br><br>
# [W 2022-01-12 20:46:56,203] The parameter 'actual_estimator__num_leaves' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,207] The parameter 'actual_estimator__learning_rate' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,210] The parameter 'actual_estimator__n_estimators' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,214] The parameter 'actual_estimator__min_split_gain' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,216] The parameter 'actual_estimator__reg_alpha' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,219] The parameter 'actual_estimator__reg_lambda' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,223] The parameter 'actual_estimator__feature_fraction' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,226] The parameter 'actual_estimator__bagging_fraction' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,229] The parameter 'actual_estimator__bagging_freq' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,233] The parameter 'actual_estimator__min_child_samples' in trial#10 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,360] The parameter 'actual_estimator__num_leaves' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,364] The parameter 'actual_estimator__learning_rate' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,368] The parameter 'actual_estimator__n_estimators' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,371] The parameter 'actual_estimator__min_split_gain' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,374] The parameter 'actual_estimator__reg_alpha' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,376] The parameter 'actual_estimator__reg_lambda' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,380] The parameter 'actual_estimator__feature_fraction' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,383] The parameter 'actual_estimator__bagging_fraction' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,386] The parameter 'actual_estimator__bagging_freq' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,389] The parameter 'actual_estimator__min_child_samples' in trial#11 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,517] The parameter 'actual_estimator__num_leaves' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,522] The parameter 'actual_estimator__learning_rate' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,525] The parameter 'actual_estimator__n_estimators' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,528] The parameter 'actual_estimator__min_split_gain' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,531] The parameter 'actual_estimator__reg_alpha' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,535] The parameter 'actual_estimator__reg_lambda' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,538] The parameter 'actual_estimator__feature_fraction' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,541] The parameter 'actual_estimator__bagging_fraction' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,545] The parameter 'actual_estimator__bagging_freq' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,548] The parameter 'actual_estimator__min_child_samples' in trial#12 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,674] The parameter 'actual_estimator__num_leaves' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,678] The parameter 'actual_estimator__learning_rate' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,682] The parameter 'actual_estimator__n_estimators' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,686] The parameter 'actual_estimator__min_split_gain' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,688] The parameter 'actual_estimator__reg_alpha' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,692] The parameter 'actual_estimator__reg_lambda' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,695] The parameter 'actual_estimator__feature_fraction' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,699] The parameter 'actual_estimator__bagging_fraction' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,702] The parameter 'actual_estimator__bagging_freq' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,705] The parameter 'actual_estimator__min_child_samples' in trial#13 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,831] The parameter 'actual_estimator__num_leaves' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,835] The parameter 'actual_estimator__learning_rate' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,838] The parameter 'actual_estimator__n_estimators' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,842] The parameter 'actual_estimator__min_split_gain' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,845] The parameter 'actual_estimator__reg_alpha' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,847] The parameter 'actual_estimator__reg_lambda' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,850] The parameter 'actual_estimator__feature_fraction' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,854] The parameter 'actual_estimator__bagging_fraction' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,858] The parameter 'actual_estimator__bagging_freq' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,860] The parameter 'actual_estimator__min_child_samples' in trial#14 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,990] The parameter 'actual_estimator__num_leaves' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,994] The parameter 'actual_estimator__learning_rate' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:56,998] The parameter 'actual_estimator__n_estimators' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,001] The parameter 'actual_estimator__min_split_gain' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,004] The parameter 'actual_estimator__reg_alpha' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,007] The parameter 'actual_estimator__reg_lambda' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,011] The parameter 'actual_estimator__feature_fraction' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,014] The parameter 'actual_estimator__bagging_fraction' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,018] The parameter 'actual_estimator__bagging_freq' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,021] The parameter 'actual_estimator__min_child_samples' in trial#15 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,147] The parameter 'actual_estimator__num_leaves' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,151] The parameter 'actual_estimator__learning_rate' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,154] The parameter 'actual_estimator__n_estimators' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,158] The parameter 'actual_estimator__min_split_gain' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,161] The parameter 'actual_estimator__reg_alpha' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,164] The parameter 'actual_estimator__reg_lambda' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,166] The parameter 'actual_estimator__feature_fraction' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,170] The parameter 'actual_estimator__bagging_fraction' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,173] The parameter 'actual_estimator__bagging_freq' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,176] The parameter 'actual_estimator__min_child_samples' in trial#16 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,306] The parameter 'actual_estimator__num_leaves' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,310] The parameter 'actual_estimator__learning_rate' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,313] The parameter 'actual_estimator__n_estimators' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,317] The parameter 'actual_estimator__min_split_gain' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,320] The parameter 'actual_estimator__reg_alpha' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,324] The parameter 'actual_estimator__reg_lambda' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,327] The parameter 'actual_estimator__feature_fraction' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,330] The parameter 'actual_estimator__bagging_fraction' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,333] The parameter 'actual_estimator__bagging_freq' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,337] The parameter 'actual_estimator__min_child_samples' in trial#17 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,462] The parameter 'actual_estimator__num_leaves' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,466] The parameter 'actual_estimator__learning_rate' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,470] The parameter 'actual_estimator__n_estimators' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,473] The parameter 'actual_estimator__min_split_gain' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,476] The parameter 'actual_estimator__reg_alpha' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,479] The parameter 'actual_estimator__reg_lambda' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,482] The parameter 'actual_estimator__feature_fraction' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,486] The parameter 'actual_estimator__bagging_fraction' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,489] The parameter 'actual_estimator__bagging_freq' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,492] The parameter 'actual_estimator__min_child_samples' in trial#18 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,620] The parameter 'actual_estimator__num_leaves' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,624] The parameter 'actual_estimator__learning_rate' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,628] The parameter 'actual_estimator__n_estimators' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,632] The parameter 'actual_estimator__min_split_gain' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,635] The parameter 'actual_estimator__reg_alpha' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,638] The parameter 'actual_estimator__reg_lambda' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,642] The parameter 'actual_estimator__feature_fraction' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,645] The parameter 'actual_estimator__bagging_fraction' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,649] The parameter 'actual_estimator__bagging_freq' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,652] The parameter 'actual_estimator__min_child_samples' in trial#19 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,890] The parameter 'actual_estimator__num_leaves' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,894] The parameter 'actual_estimator__learning_rate' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,898] The parameter 'actual_estimator__n_estimators' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,902] The parameter 'actual_estimator__min_split_gain' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,905] The parameter 'actual_estimator__reg_alpha' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,908] The parameter 'actual_estimator__reg_lambda' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,911] The parameter 'actual_estimator__feature_fraction' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,915] The parameter 'actual_estimator__bagging_fraction' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,918] The parameter 'actual_estimator__bagging_freq' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:57,922] The parameter 'actual_estimator__min_child_samples' in trial#20 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,049] The parameter 'actual_estimator__num_leaves' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,053] The parameter 'actual_estimator__learning_rate' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,057] The parameter 'actual_estimator__n_estimators' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,061] The parameter 'actual_estimator__min_split_gain' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,064] The parameter 'actual_estimator__reg_alpha' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,068] The parameter 'actual_estimator__reg_lambda' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,071] The parameter 'actual_estimator__feature_fraction' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,074] The parameter 'actual_estimator__bagging_fraction' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,077] The parameter 'actual_estimator__bagging_freq' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,081] The parameter 'actual_estimator__min_child_samples' in trial#21 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,209] The parameter 'actual_estimator__num_leaves' in trial#22 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,213] The parameter 'actual_estimator__learning_rate' in trial#22 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,217] The parameter 'actual_estimator__n_estimators' in trial#22 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,220] The parameter 'actual_estimator__min_split_gain' in trial#22 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,224] The parameter 'actual_estimator__reg_alpha' in trial#22 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:58,227] The parameter 'actual_estimator__reg_lambda' in trial#22 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# ...
# [W 2022-01-12 20:46:59,014] The parameter 'actual_estimator__bagging_freq' in trial#26 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,019] The parameter 'actual_estimator__min_child_samples' in trial#26 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,264] The parameter 'actual_estimator__num_leaves' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,269] The parameter 'actual_estimator__learning_rate' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,272] The parameter 'actual_estimator__n_estimators' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,276] The parameter 'actual_estimator__min_split_gain' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,280] The parameter 'actual_estimator__reg_alpha' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,284] The parameter 'actual_estimator__reg_lambda' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,288] The parameter 'actual_estimator__feature_fraction' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,291] The parameter 'actual_estimator__bagging_fraction' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,294] The parameter 'actual_estimator__bagging_freq' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,298] The parameter 'actual_estimator__min_child_samples' in trial#27 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,436] The parameter 'actual_estimator__num_leaves' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,441] The parameter 'actual_estimator__learning_rate' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,445] The parameter 'actual_estimator__n_estimators' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,449] The parameter 'actual_estimator__min_split_gain' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,453] The parameter 'actual_estimator__reg_alpha' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,456] The parameter 'actual_estimator__reg_lambda' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,460] The parameter 'actual_estimator__feature_fraction' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,464] The parameter 'actual_estimator__bagging_fraction' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,468] The parameter 'actual_estimator__bagging_freq' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,472] The parameter 'actual_estimator__min_child_samples' in trial#28 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,611] The parameter 'actual_estimator__num_leaves' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,616] The parameter 'actual_estimator__learning_rate' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,619] The parameter 'actual_estimator__n_estimators' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,623] The parameter 'actual_estimator__min_split_gain' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,627] The parameter 'actual_estimator__reg_alpha' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,631] The parameter 'actual_estimator__reg_lambda' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,635] The parameter 'actual_estimator__feature_fraction' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,639] The parameter 'actual_estimator__bagging_fraction' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,643] The parameter 'actual_estimator__bagging_freq' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,647] The parameter 'actual_estimator__min_child_samples' in trial#29 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,782] The parameter 'actual_estimator__num_leaves' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,786] The parameter 'actual_estimator__learning_rate' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,789] The parameter 'actual_estimator__n_estimators' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,793] The parameter 'actual_estimator__min_split_gain' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,797] The parameter 'actual_estimator__reg_alpha' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,800] The parameter 'actual_estimator__reg_lambda' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,804] The parameter 'actual_estimator__feature_fraction' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,809] The parameter 'actual_estimator__bagging_fraction' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,812] The parameter 'actual_estimator__bagging_freq' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
# [W 2022-01-12 20:46:59,817] The parameter 'actual_estimator__min_child_samples' in trial#30 is sampled independently instead of being sampled by multivariate TPE sampler. (optimization performance may be degraded). You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `TPESampler`, if this independent sampling is intended behavior.
